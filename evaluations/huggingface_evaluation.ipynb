# %%
from datasets import load_dataset
from transformers import pipeline
from transformers import AutoConfig
import torch
from transformers import AutoModelForTokenClassification, AutoTokenizer
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import numpy as np

# %% [markdown]
# #### Load the dataset

# %%
dataset_name = "ai4privacy/pii-masking-200k"

# %%
samples = 10

# %%
model_name = "Isotonic/deberta-v3-base_finetuned_ai4privacy_v2"

# %%
def load_data(dataset_name):
    dataset = load_dataset(dataset_name)
    filtered_dataset = dataset.filter(lambda example: example['language'] == 'en')
    df = filtered_dataset['train'].to_pandas() 
    df.head()
    return df

# %%
df = load_data(dataset_name=dataset_name)

# %%
def filtered_dataset(rows, df):
    return df.head(rows)

# %%
df_filtered = filtered_dataset(samples, df)

# %% [markdown]
# getting the label list the model is trained on

# %%
config = AutoConfig.from_pretrained(model_name)
label_list = list(config.id2label.values())
print(label_list)
# Out:
# ['O', 'B-CITY', 'I-CITY', 'B-FIRSTNAME', 'I-FIRSTNAME', 'B-USERNAME', 'I-USERNAME', 'B-JOBTYPE', 'B-PREFIX', 'I-PREFIX', 'B-LASTNAME', 'B-EMAIL', 'I-EMAIL', 'B-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'B-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'B-ACCOUNTNAME', 'I-ACCOUNTNAME', 'B-MIDDLENAME', 'I-MIDDLENAME', 'B-COUNTY', 'I-COUNTY', 'B-AGE', 'B-CREDITCARDCVV', 'B-DOB', 'I-DOB', 'B-MASKEDNUMBER', 'I-MASKEDNUMBER', 'B-PASSWORD', 'I-PASSWORD', 'B-SEX', 'B-STATE', 'B-COMPANYNAME', 'I-COMPANYNAME', 'B-PHONEIMEI', 'I-PHONEIMEI', 'B-STREET', 'I-STREET', 'B-SSN', 'I-SSN', 'B-IPV4', 'I-IPV4', 'B-USERAGENT', 'I-USERAGENT', 'B-MAC', 'I-MAC', 'B-PIN', 'I-PIN', 'B-IP', 'I-IP', 'B-URL', 'I-URL', 'B-CURRENCYSYMBOL', 'B-DATE', 'I-DATE', 'B-TIME', 'I-TIME', 'B-VEHICLEVRM', 'I-VEHICLEVRM', 'I-AMOUNT', 'B-ETHEREUMADDRESS', 'I-ETHEREUMADDRESS', 'B-BITCOINADDRESS', 'I-BITCOINADDRESS', 'B-LITECOINADDRESS', 'I-LITECOINADDRESS', 'I-JOBTYPE', 'B-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'B-IPV6', 'I-IPV6', 'I-LASTNAME', 'B-PHONENUMBER', 'I-PHONENUMBER', 'B-CREDITCARDISSUER', 'I-CREDITCARDISSUER', 'B-SECONDARYADDRESS', 'I-SECONDARYADDRESS', 'B-ZIPCODE', 'I-ZIPCODE', 'B-VEHICLEVIN', 'I-VEHICLEVIN', 'I-AGE', 'B-GENDER', 'I-GENDER', 'B-ORDINALDIRECTION', 'B-JOBAREA', 'B-HEIGHT', 'I-HEIGHT', 'B-JOBTITLE', 'I-JOBTITLE', 'B-BUILDINGNUMBER', 'I-BUILDINGNUMBER', 'B-AMOUNT', 'I-STATE', 'I-CURRENCYSYMBOL', 'B-IBAN', 'I-IBAN', 'B-BIC', 'I-BIC', 'B-EYECOLOR', 'B-CURRENCYNAME', 'I-CURRENCYNAME', 'B-CURRENCY', 'I-CURRENCY', 'B-CURRENCYCODE', 'I-CURRENCYCODE', 'I-JOBAREA', 'I-EYECOLOR', 'I-CREDITCARDCVV']

# %% [markdown]
# #### Load the model and tokenizer

# %%
model = AutoModelForTokenClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
df_filtered['source_text']  #viewing the source text to test
# Out:
# 0    A student's assessment was found on device bea...
# 1    Dear Omer, as per our records, your license 78...
# 2    Kattie could you please share your recomndatio...
# 3    Emergency supplies in 16356 need a refill. Use...
# 4    The 88 old child at 5862, has showcased an unu...
# 5    Your recent hospital data recorded on 29/12/19...
# 6    Dear Trans male, Let's clear this misunderstan...
# 7    The wellness portal is accessible at [-71.6702...
# 8    Carleton, the new interactive educational tool...
# 9    1. Customer query received at 10:18 PM from Hu...
# Name: source_text, dtype: object

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
# Out:
# DebertaV2ForTokenClassification(
#   (deberta): DebertaV2Model(
#     (embeddings): DebertaV2Embeddings(
#       (word_embeddings): Embedding(128100, 768, padding_idx=0)
#       (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): DebertaV2Encoder(
#       (layer): ModuleList(
#         (0-11): 12 x DebertaV2Layer(
#           (attention): DebertaV2Attention(
#             (self): DisentangledSelfAttention(
#               (query_proj): Linear(in_features=768, out_features=768, bias=True)
#               (key_proj): Linear(in_features=768, out_features=768, bias=True)
#               (value_proj): Linear(in_features=768, out_features=768, bias=True)
#               (pos_dropout): Dropout(p=0.1, inplace=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): DebertaV2SelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): DebertaV2Intermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaV2Output(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (rel_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=111, bias=True)
# )

# %%
#get the tokens of the test data sentence, since it is present in the dataset 
test_texts = [list(arr) for arr in df_filtered['mbert_text_tokens'].tolist()]

# %%
type(test_texts)
# Out:
# list

# %%
type(test_texts[0])
# Out:
# list

# %%
true_labels = df_filtered['mbert_bio_labels'].tolist() #ground truth of label list for the filtered dataset

# %%
true_labels[0]
# Out:
# array(['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'O', 'B-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI',
#        'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI',
#        'I-PHONEIMEI', 'I-PHONEIMEI', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'O', 'O', 'O', 'O', 'B-JOBAREA', 'I-JOBAREA', 'I-JOBAREA', 'O',
#        'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], dtype=object)

# %%
type(true_labels[0])
# Out:
# numpy.ndarray

# %%
encodings = tokenizer(
    test_texts,
    truncation=True,
    padding=True,
    max_length=512,
    return_tensors="pt",
    is_split_into_words=True, 
    return_offsets_mapping=True
)

model_inputs = {key: val for key, val in encodings.items() if key != "offset_mapping"}

# %%
type(df_filtered['mbert_text_tokens'][1].tolist())
# Out:
# list

# %%
all_aligned_predictions = []  # Store predictions for all sentences
all_aligned_tokens = []

for i in range(len(df_filtered)):  # Loop through all sentences
    
    encodings = tokenizer(
        df_filtered['mbert_text_tokens'][i].tolist(),
        truncation=True,
        padding=True,
        max_length=512,
        return_tensors="pt",
        is_split_into_words=True, 
        return_offsets_mapping=True
    )

    tokens = tokenizer.convert_ids_to_tokens(encodings["input_ids"][0])  
    word_ids = encodings.word_ids()
    
    # Filter tokens to only keep the first subword of each word
    filtered_tokens = []
    filtered_word_ids = set()

    for token, word_id in zip(tokens, word_ids):
        if word_id is not None and word_id not in filtered_word_ids:
            filtered_tokens.append(token)
            filtered_word_ids.add(word_id)

    model_inputs = {key: val for key, val in encodings.items() if key != "offset_mapping"}

    # Get model predictions
    with torch.no_grad():
        outputs = model(**model_inputs)

    logits = outputs.logits  # Shape: (batch_size, seq_length, num_labels)
    predictions = torch.argmax(logits, dim=-1).cpu().numpy()  # Get predicted class indices

    # Map predictions to original tokens
    aligned_predictions = []
    aligned_tokens = []
    previous_word_id = None

    # Align predictions with words
    for token, word_id, pred in zip(tokens, word_ids, predictions[0]):  
        if word_id is None:  
            continue  # Skip special tokens ([CLS], [SEP], etc.)

        if word_id != previous_word_id:  # Only take the first subword's prediction
            aligned_predictions.append(label_list[pred])
            aligned_tokens.append(token)

        previous_word_id = word_id 

    # Store predictions for this sentence
    all_aligned_predictions.append(aligned_predictions)
    all_aligned_tokens.append(aligned_tokens)

# %%
for i, (sentence, preds) in enumerate(zip(df_filtered['source_text'], all_aligned_predictions)):
    print(f"Sentence {i+1}: {sentence}")
    print(f"Length of actual label list = \n {len(true_labels[i])}")
    print(f"Actual Tokens {df_filtered['mbert_text_tokens'][i]}\n")
    print(f"Predicted Aligned Tokens: {all_aligned_tokens[i]}\n")
    print(f"Predicted Aligned Tokens: {len(all_aligned_tokens[i])}\n")
    print(f"Length of predicted label list = \n {len(preds)}")
    print(f"Actual Labels: {true_labels[i]}")
    print(f"Predicted Labels: {preds}")
    print("-" * 50)
# Out:
# Sentence 1: A student's assessment was found on device bearing IMEI: 06-184755-866851-3. The document falls under the various topics discussed in our Optimization curriculum. Can you please collect it?
# Length of actual label list =
#  48
# Actual Tokens ['A' 'student' "'" 's' 'assessment' 'was' 'found' 'on' 'device' 'bearing'
#  'IM' '##E' '##I' ':' '06' '-' '1847' '##55' '-' '866' '##85' '##1' '-'
#  '3' '.' 'The' 'document' 'falls' 'under' 'the' 'various' 'topics'
#  'discussed' 'in' 'our' 'Op' '##timi' '##zation' 'curriculum' '.' 'Can'
#  'you' 'pl' '##eas' '##e' 'collect' 'it' '?']
#
# Predicted Aligned Tokens: ['▁A', '▁student', "▁'", '▁s', '▁assessment', '▁was', '▁found', '▁on', '▁device', '▁bearing', '▁IM', '▁#', '▁#', '▁:', '▁06', '▁-', '▁1847', '▁#', '▁-', '▁866', '▁#', '▁#', '▁-', '▁3', '▁.', '▁The', '▁document', '▁falls', '▁under', '▁the', '▁various', '▁topics', '▁discussed', '▁in', '▁our', '▁Op', '▁#', '▁#', '▁curriculum', '▁.', '▁Can', '▁you', '▁pl', '▁#', '▁#', '▁collect', '▁it', '▁?']
#
# Predicted Aligned Tokens: 48
#
# Length of predicted label list =
#  48
# Actual Labels: ['O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-PHONEIMEI'
#  'I-PHONEIMEI' 'I-PHONEIMEI' 'I-PHONEIMEI' 'I-PHONEIMEI' 'I-PHONEIMEI'
#  'I-PHONEIMEI' 'I-PHONEIMEI' 'I-PHONEIMEI' 'I-PHONEIMEI' 'O' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-JOBAREA' 'I-JOBAREA' 'I-JOBAREA' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O']
# Predicted Labels: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-JOBAREA', 'I-JOBAREA', 'I-JOBAREA', 'O', 'O', 'O', 'O', 'B-FIRSTNAME', 'I-FIRSTNAME', 'I-FIRSTNAME', 'O', 'O', 'O']
# --------------------------------------------------
# Sentence 2: Dear Omer, as per our records, your license 78B5R2MVFAHJ48500 is still registered in our records for access to the educational tools. Please feedback on it's operability.
# Length of actual label list =
#  45
# Actual Tokens ['Dear' 'Omer' ',' 'as' 'per' 'our' 'records' ',' 'your' 'license' '78'
#  '##B' '##5' '##R' '##2' '##M' '##V' '##FA' '##H' '##J' '##48' '##50'
#  '##0' 'is' 'still' 'registered' 'in' 'our' 'records' 'for' 'access' 'to'
#  'the' 'educational' 'tools' '.' 'Please' 'feedback' 'on' 'it' "'" 's'
#  'opera' '##bility' '.']
#
# Predicted Aligned Tokens: ['▁Dear', '▁Omer', '▁,', '▁as', '▁per', '▁our', '▁records', '▁,', '▁your', '▁license', '▁78', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁is', '▁still', '▁registered', '▁in', '▁our', '▁records', '▁for', '▁access', '▁to', '▁the', '▁educational', '▁tools', '▁.', '▁Please', '▁feedback', '▁on', '▁it', "▁'", '▁s', '▁opera', '▁#', '▁.']
#
# Predicted Aligned Tokens: 45
#
# Length of predicted label list =
#  45
# Actual Labels: ['O' 'B-FIRSTNAME' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-VEHICLEVIN'
#  'I-VEHICLEVIN' 'I-VEHICLEVIN' 'I-VEHICLEVIN' 'I-VEHICLEVIN'
#  'I-VEHICLEVIN' 'I-VEHICLEVIN' 'I-VEHICLEVIN' 'I-VEHICLEVIN'
#  'I-VEHICLEVIN' 'I-VEHICLEVIN' 'I-VEHICLEVIN' 'I-VEHICLEVIN' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'O']
# Predicted Labels: ['O', 'B-FIRSTNAME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# --------------------------------------------------
# Sentence 3: Kattie could you please share your recomndations about vegetarian diet for 72 old Intersex person with 158centimeters?
# Length of actual label list =
#  31
# Actual Tokens ['Kat' '##tie' 'could' 'you' 'pl' '##eas' '##e' 'share' 'your' 're'
#  '##com' '##nda' '##tions' 'about' 'veg' '##etaria' '##n' 'diet' 'for'
#  '72' 'old' 'Inter' '##se' '##x' 'person' 'with' '158' '##cent' '##imet'
#  '##ers' '?']
#
# Predicted Aligned Tokens: ['▁Kat', '▁#', '▁could', '▁you', '▁pl', '▁#', '▁#', '▁share', '▁your', '▁re', '▁#', '▁#', '▁#', '▁about', '▁veg', '▁#', '▁#', '▁diet', '▁for', '▁72', '▁old', '▁Inter', '▁#', '▁#', '▁person', '▁with', '▁158', '▁#', '▁#', '▁#', '▁?']
#
# Predicted Aligned Tokens: 31
#
# Length of predicted label list =
#  31
# Actual Labels: ['B-FIRSTNAME' 'I-FIRSTNAME' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'B-AGE' 'O' 'B-GENDER' 'I-GENDER' 'I-GENDER'
#  'I-GENDER' 'O' 'B-HEIGHT' 'I-HEIGHT' 'I-HEIGHT' 'I-HEIGHT' 'O']
# Predicted Labels: ['B-FIRSTNAME', 'I-FIRSTNAME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-AGE', 'O', 'B-GENDER', 'I-GENDER', 'I-GENDER', 'I-GENDER', 'O', 'B-HEIGHT', 'I-HEIGHT', 'I-HEIGHT', 'I-HEIGHT', 'O']
# --------------------------------------------------
# Sentence 4: Emergency supplies in 16356 need a refill. Use 5890724654311332 to pay for them.
# Length of actual label list =
#  25
# Actual Tokens ['Emergency' 'supplies' 'in' '1635' '##6' 'need' 'a' 'ref' '##ill' '.'
#  'Use' '589' '##0' '##7' '##24' '##65' '##43' '##11' '##33' '##2' 'to'
#  'pay' 'for' 'them' '.']
#
# Predicted Aligned Tokens: ['▁Emergency', '▁supplies', '▁in', '▁16', '▁#', '▁need', '▁a', '▁ref', '▁#', '▁.', '▁Use', '▁589', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁to', '▁pay', '▁for', '▁them', '▁.']
#
# Predicted Aligned Tokens: 25
#
# Length of predicted label list =
#  25
# Actual Labels: ['O' 'O' 'O' 'B-BUILDINGNUMBER' 'I-BUILDINGNUMBER' 'O' 'O' 'O' 'O' 'O' 'O'
#  'B-MASKEDNUMBER' 'I-MASKEDNUMBER' 'I-MASKEDNUMBER' 'I-MASKEDNUMBER'
#  'I-MASKEDNUMBER' 'I-MASKEDNUMBER' 'I-MASKEDNUMBER' 'I-MASKEDNUMBER'
#  'I-MASKEDNUMBER' 'O' 'O' 'O' 'O' 'O']
# Predicted Labels: ['O', 'O', 'O', 'B-ZIPCODE', 'I-ZIPCODE', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'O', 'O', 'O', 'O', 'O']
# --------------------------------------------------
# Sentence 5: The 88 old child at 5862, has showcased an unusual ability to remember and recite passwords, with Y2rWliOhf8Ir being most repeated.
# Length of actual label list =
#  40
# Actual Tokens ['The' '88' 'old' 'child' 'at' '586' '##2' ',' 'has' 'show' '##case' '##d'
#  'an' 'unusual' 'ability' 'to' 'remember' 'and' 're' '##cite' 'pass'
#  '##word' '##s' ',' 'with' 'Y' '##2' '##r' '##W' '##li' '##O' '##h' '##f'
#  '##8' '##I' '##r' 'being' 'most' 'repeated' '.']
#
# Predicted Aligned Tokens: ['▁The', '▁88', '▁old', '▁child', '▁at', '▁586', '▁#', '▁,', '▁has', '▁show', '▁#', '▁#', '▁an', '▁unusual', '▁ability', '▁to', '▁remember', '▁and', '▁re', '▁#', '▁pass', '▁#', '▁#', '▁,', '▁with', '▁Y', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁being', '▁most', '▁repeated', '▁.']
#
# Predicted Aligned Tokens: 40
#
# Length of predicted label list =
#  40
# Actual Labels: ['O' 'B-AGE' 'O' 'O' 'O' 'B-BUILDINGNUMBER' 'I-BUILDINGNUMBER' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-PASSWORD'
#  'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD'
#  'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'O' 'O'
#  'O' 'O']
# Predicted Labels: ['O', 'B-AGE', 'O', 'O', 'O', 'B-BUILDINGNUMBER', 'I-BUILDINGNUMBER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'O', 'O', 'O', 'O']
# --------------------------------------------------
# Sentence 6: Your recent hospital data recorded on 29/12/1957 regarding chronic disease management has been encrypted with IPv6 edaf:fd8f:e1e8:cfec:8bab:1afd:6aad:550c for enhanced privacy.
# Length of actual label list =
#  58
# Actual Tokens ['Your' 'recent' 'hospital' 'data' 'recorded' 'on' '29' '/' '12' '/'
#  '1957' 'regarding' 'chronic' 'disease' 'management' 'has' 'been' 'en'
#  '##c' '##ry' '##pted' 'with' 'IP' '##v' '##6' 'ed' '##af' ':' 'f' '##d'
#  '##8' '##f' ':' 'e' '##1' '##e' '##8' ':' 'cf' '##ec' ':' '8' '##bab' ':'
#  '1a' '##f' '##d' ':' '6' '##aad' ':' '550' '##c' 'for' 'enhanced' 'pri'
#  '##vacy' '.']
#
# Predicted Aligned Tokens: ['▁Your', '▁recent', '▁hospital', '▁data', '▁recorded', '▁on', '▁29', '▁/', '▁12', '▁/', '▁1957', '▁regarding', '▁chronic', '▁disease', '▁management', '▁has', '▁been', '▁en', '▁#', '▁#', '▁#', '▁with', '▁IP', '▁#', '▁#', '▁ed', '▁#', '▁:', '▁f', '▁#', '▁#', '▁#', '▁:', '▁e', '▁#', '▁#', '▁#', '▁:', '▁cf', '▁#', '▁:', '▁8', '▁#', '▁:', '▁1', '▁#', '▁#', '▁:', '▁6', '▁#', '▁:', '▁550', '▁#', '▁for', '▁enhanced', '▁pri', '▁#', '▁.']
#
# Predicted Aligned Tokens: 58
#
# Length of predicted label list =
#  58
# Actual Labels: ['O' 'O' 'O' 'O' 'O' 'O' 'B-DOB' 'I-DOB' 'I-DOB' 'I-DOB' 'I-DOB' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-IPV6' 'I-IPV6'
#  'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6'
#  'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6'
#  'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6'
#  'I-IPV6' 'I-IPV6' 'O' 'O' 'O' 'O' 'O']
# Predicted Labels: ['O', 'O', 'O', 'O', 'O', 'O', 'B-DOB', 'I-DOB', 'I-DOB', 'I-DOB', 'I-DOB', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'O', 'O', 'O', 'O', 'O']
# --------------------------------------------------
# Sentence 7: Dear Trans male, Let's clear this misunderstanding. We never send an email asking for your E5_N8G2xWM6D. If you get one, it's not from us. Please secure your account. If you already gave out your password, change it immediately.
# Length of actual label list =
#  66
# Actual Tokens ['Dear' 'Trans' 'male' ',' 'Let' "'" 's' 'clear' 'this' 'mis' '##unde'
#  '##rst' '##andi' '##ng' '.' 'We' 'never' 'send' 'an' 'email' 'asking'
#  'for' 'your' 'E' '##5' '_' 'N' '##8' '##G' '##2' '##x' '##W' '##M' '##6'
#  '##D' '.' 'If' 'you' 'get' 'one' ',' 'it' "'" 's' 'not' 'from' 'us' '.'
#  'Please' 'secure' 'your' 'account' '.' 'If' 'you' 'already' 'gave' 'out'
#  'your' 'pass' '##word' ',' 'change' 'it' 'immediately' '.']
#
# Predicted Aligned Tokens: ['▁Dear', '▁Trans', '▁male', '▁,', '▁Let', "▁'", '▁s', '▁clear', '▁this', '▁mis', '▁#', '▁#', '▁#', '▁#', '▁.', '▁We', '▁never', '▁send', '▁an', '▁email', '▁asking', '▁for', '▁your', '▁E', '▁#', '▁_', '▁N', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁.', '▁If', '▁you', '▁get', '▁one', '▁,', '▁it', "▁'", '▁s', '▁not', '▁from', '▁us', '▁.', '▁Please', '▁secure', '▁your', '▁account', '▁.', '▁If', '▁you', '▁already', '▁gave', '▁out', '▁your', '▁pass', '▁#', '▁,', '▁change', '▁it', '▁immediately', '▁.']
#
# Predicted Aligned Tokens: 66
#
# Length of predicted label list =
#  66
# Actual Labels: ['O' 'B-GENDER' 'I-GENDER' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-PASSWORD' 'I-PASSWORD' 'I-PASSWORD'
#  'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD'
#  'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'O' 'O' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O']
# Predicted Labels: ['O', 'B-GENDER', 'I-GENDER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# --------------------------------------------------
# Sentence 8: The wellness portal is accessible at [-71.6702,-107.6572]. With numerous wellness tracks suitable for everyone in the family, enrol now! Contact us at Mozilla/5.0 (Macintosh; PPC Mac OS X 10.7.5; rv:12.5) Gecko/20100101 Firefox/12.5.9 for further details.
# Length of actual label list =
#  83
# Actual Tokens ['The' 'well' '##ness' 'portal' 'is' 'accessible' 'at' '[' '-' '71' '.'
#  '670' '##2' ',' '-' '107' '.' '657' '##2' ']' '.' 'With' 'numerous'
#  'well' '##ness' 'tracks' 'suitable' 'for' 'everyone' 'in' 'the' 'family'
#  ',' 'en' '##rol' 'now' '!' 'Contact' 'us' 'at' 'Mozilla' '/' '5' '.' '0'
#  '(' 'Macintosh' ';' 'PP' '##C' 'Mac' 'OS' 'X' '10' '.' '7' '.' '5' ';'
#  'r' '##v' ':' '12' '.' '5' ')' 'G' '##ecko' '/' '2010' '##01' '##01'
#  'Firefox' '/' '12' '.' '5' '.' '9' 'for' 'further' 'details' '.']
#
# Predicted Aligned Tokens: ['▁The', '▁well', '▁#', '▁portal', '▁is', '▁accessible', '▁at', '▁[', '▁-', '▁71', '▁.', '▁670', '▁#', '▁,', '▁-', '▁107', '▁.', '▁657', '▁#', '▁]', '▁.', '▁With', '▁numerous', '▁well', '▁#', '▁tracks', '▁suitable', '▁for', '▁everyone', '▁in', '▁the', '▁family', '▁,', '▁en', '▁#', '▁now', '▁!', '▁Contact', '▁us', '▁at', '▁Mozilla', '▁/', '▁5', '▁.', '▁0', '▁(', '▁Macintosh', '▁;', '▁PP', '▁#', '▁Mac', '▁OS', '▁X', '▁10', '▁.', '▁7', '▁.', '▁5', '▁;', '▁r', '▁#', '▁:', '▁12', '▁.', '▁5', '▁)', '▁G', '▁#', '▁/', '▁2010', '▁#', '▁#', '▁Firefox', '▁/', '▁12', '▁.', '▁5', '▁.', '▁9', '▁for', '▁further', '▁details', '▁.']
#
# Predicted Aligned Tokens: 83
#
# Length of predicted label list =
#  83
# Actual Labels: ['O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-NEARBYGPSCOORDINATE'
#  'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'O' 'O' 'B-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT'
#  'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT'
#  'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT'
#  'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT'
#  'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT'
#  'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT'
#  'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT'
#  'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'O'
#  'O' 'O' 'O']
# Predicted Labels: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'O', 'O', 'O', 'O']
# --------------------------------------------------
# Sentence 9: Carleton, the new interactive educational tools are set to arrive at [-38.9302,113.5422]. Your password for accessing online content: yZqd7gHyZq91.
# Length of actual label list =
#  46
# Actual Tokens ['Carleton' ',' 'the' 'new' 'interactive' 'educational' 'tools' 'are'
#  'set' 'to' 'arrive' 'at' '[' '-' '38' '.' '930' '##2' ',' '113' '.' '542'
#  '##2' ']' '.' 'Your' 'pass' '##word' 'for' 'access' '##ing' 'online'
#  'content' ':' 'y' '##Z' '##q' '##d' '##7' '##g' '##H' '##y' '##Z' '##q'
#  '##91' '.']
#
# Predicted Aligned Tokens: ['▁Carleton', '▁,', '▁the', '▁new', '▁interactive', '▁educational', '▁tools', '▁are', '▁set', '▁to', '▁arrive', '▁at', '▁[', '▁-', '▁38', '▁.', '▁930', '▁#', '▁,', '▁113', '▁.', '▁542', '▁#', '▁]', '▁.', '▁Your', '▁pass', '▁#', '▁for', '▁access', '▁#', '▁online', '▁content', '▁:', '▁y', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁#', '▁.']
#
# Predicted Aligned Tokens: 46
#
# Length of predicted label list =
#  46
# Actual Labels: ['B-FIRSTNAME' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'B-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-PASSWORD' 'I-PASSWORD'
#  'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD'
#  'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'O']
# Predicted Labels: ['B-FIRSTNAME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'O']
# --------------------------------------------------
# Sentence 10: 1. Customer query received at 10:18 PM from Human Group Coordinator of Cleveland based firm. The customer's email is Emilie_Beatty53@hotmail.com. Use our account number 63652332 for all financial exchanges. For personal discussions, ensure privacy with PIN - 8824 and EYECOLOR - Eye color: Brown.
# Length of actual label list =
#  77
# Actual Tokens ['1' '.' 'Custom' '##er' 'quer' '##y' 'received' 'at' '10' ':' '18' 'PM'
#  'from' 'Human' 'Group' 'Co' '##ordinator' 'of' 'Cleveland' 'based' 'firm'
#  '.' 'The' 'customer' "'" 's' 'email' 'is' 'Emilie' '_' 'Beatty' '##53'
#  '@' 'hot' '##mail' '.' 'com' '.' 'Use' 'our' 'account' 'number' '636'
#  '##52' '##33' '##2' 'for' 'all' 'financial' 'exchange' '##s' '.' 'For'
#  'personal' 'discussions' ',' 'ensure' 'pri' '##vacy' 'with' 'P' '##IN'
#  '-' '882' '##4' 'and' 'E' '##Y' '##EC' '##OL' '##OR' '-' 'Eye' 'color'
#  ':' 'Brown' '.']
#
# Predicted Aligned Tokens: ['▁1', '▁.', '▁Custom', '▁#', '▁que', '▁#', '▁received', '▁at', '▁10', '▁:', '▁18', '▁PM', '▁from', '▁Human', '▁Group', '▁Co', '▁#', '▁of', '▁Cleveland', '▁based', '▁firm', '▁.', '▁The', '▁customer', "▁'", '▁s', '▁email', '▁is', '▁Emilie', '▁_', '▁Beatty', '▁#', '▁@', '▁hot', '▁#', '▁.', '▁com', '▁.', '▁Use', '▁our', '▁account', '▁number', '▁636', '▁#', '▁#', '▁#', '▁for', '▁all', '▁financial', '▁exchange', '▁#', '▁.', '▁For', '▁personal', '▁discussions', '▁,', '▁ensure', '▁pri', '▁#', '▁with', '▁P', '▁#', '▁-', '▁88', '▁#', '▁and', '▁E', '▁#', '▁#', '▁#', '▁#', '▁-', '▁Eye', '▁color', '▁:', '▁Brown', '▁.']
#
# Predicted Aligned Tokens: 77
#
# Length of predicted label list =
#  77
# Actual Labels: ['O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-TIME' 'I-TIME' 'I-TIME' 'I-TIME' 'O'
#  'B-JOBTITLE' 'I-JOBTITLE' 'I-JOBTITLE' 'I-JOBTITLE' 'O' 'B-COUNTY' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-EMAIL' 'I-EMAIL' 'I-EMAIL' 'I-EMAIL'
#  'I-EMAIL' 'I-EMAIL' 'I-EMAIL' 'I-EMAIL' 'I-EMAIL' 'O' 'O' 'O' 'O' 'O'
#  'B-ACCOUNTNUMBER' 'I-ACCOUNTNUMBER' 'I-ACCOUNTNUMBER' 'I-ACCOUNTNUMBER'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'B-PIN' 'I-PIN' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-EYECOLOR' 'I-EYECOLOR'
#  'I-EYECOLOR' 'I-EYECOLOR' 'O']
# Predicted Labels: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TIME', 'I-TIME', 'I-TIME', 'I-TIME', 'O', 'B-JOBTITLE', 'I-JOBTITLE', 'I-JOBTITLE', 'I-JOBTITLE', 'O', 'B-COUNTY', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'O', 'O', 'O', 'O', 'O', 'B-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PIN', 'I-PIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EYECOLOR', 'I-EYECOLOR', 'I-EYECOLOR', 'I-EYECOLOR', 'O']
# --------------------------------------------------

# %%
# this is the code to get the predicted result for one sentence of the dataset, use this to understand how the tokens 
# made, and compare token wise the predicted labels and original labels 
index = 0
original_tokens = df_filtered['mbert_text_tokens'][index]  #ground truth of label list for the first sentence

encodings = tokenizer(
        df_filtered['mbert_text_tokens'][index].tolist(),
        truncation=True,
        padding=True,
        max_length=512,
        return_tensors="pt",
        is_split_into_words=True, 
        return_offsets_mapping=True
    )

# Maps subwords (which are broken down further by the tokenizer) to original words present in the token list originally
tokens = tokenizer.convert_ids_to_tokens(encodings["input_ids"][0])
offsets = encodings["offset_mapping"]
word_ids = encodings.word_ids()

# Select only the first subword per word to match dataset tokens
filtered_tokens = []
filtered_word_ids = set()

for token, word_id in zip(tokens, word_ids):
    if word_id is not None and word_id not in filtered_word_ids:
        filtered_tokens.append(token)
        filtered_word_ids.add(word_id)

# Print result
print("Filtered Tokens:", filtered_tokens)
print("Original Tokens:", original_tokens)

# Get model predictions
with torch.no_grad():
    outputs = model(**model_inputs)

logits = outputs.logits  # Shape: (batch_size, seq_length, num_labels)
predictions = torch.argmax(logits, dim=-1).cpu().numpy()  # Get predicted class indices

# Map predictions to original tokens
aligned_predictions = []
aligned_tokens = []
previous_word_id = None

    # Align predictions with words
for token, word_id, pred in zip(tokens, word_ids, predictions[0]):  
    if word_id is None:  
        continue  # Skip special tokens ([CLS], [SEP], etc.)

    if word_id != previous_word_id:  # Only take the first subword's prediction
        aligned_predictions.append(label_list[pred])
        aligned_tokens.append(token)

    previous_word_id = word_id 

# Print final mapped predictions
print("Original Tokens:", original_tokens)
print("Predicted Labels:", aligned_predictions)

print(f"True labels list size = {len(true_labels[index])}")
print(f"True token list size = {len(df_filtered['mbert_text_tokens'][index])}")
print(f"Predicted labels list size = {len(aligned_predictions)}")

print(f"Filtered tokens = \n {filtered_tokens}")

print(f"True label = \n {true_labels[index]} \n")
print(f"Predicted label = \n {aligned_predictions} \n")

accuracy = accuracy_score(true_labels[index], aligned_predictions)
precision, recall, f1, _ = precision_recall_fscore_support(true_labels[index], aligned_predictions, average="weighted")

# Print Evaluation Metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Filtered Tokens: ['▁A', '▁student', "▁'", '▁s', '▁assessment', '▁was', '▁found', '▁on', '▁device', '▁bearing', '▁IM', '▁#', '▁#', '▁:', '▁06', '▁-', '▁1847', '▁#', '▁-', '▁866', '▁#', '▁#', '▁-', '▁3', '▁.', '▁The', '▁document', '▁falls', '▁under', '▁the', '▁various', '▁topics', '▁discussed', '▁in', '▁our', '▁Op', '▁#', '▁#', '▁curriculum', '▁.', '▁Can', '▁you', '▁pl', '▁#', '▁#', '▁collect', '▁it', '▁?']
# Original Tokens: ['A' 'student' "'" 's' 'assessment' 'was' 'found' 'on' 'device' 'bearing'
#  'IM' '##E' '##I' ':' '06' '-' '1847' '##55' '-' '866' '##85' '##1' '-'
#  '3' '.' 'The' 'document' 'falls' 'under' 'the' 'various' 'topics'
#  'discussed' 'in' 'our' 'Op' '##timi' '##zation' 'curriculum' '.' 'Can'
#  'you' 'pl' '##eas' '##e' 'collect' 'it' '?']
# Original Tokens: ['A' 'student' "'" 's' 'assessment' 'was' 'found' 'on' 'device' 'bearing'
#  'IM' '##E' '##I' ':' '06' '-' '1847' '##55' '-' '866' '##85' '##1' '-'
#  '3' '.' 'The' 'document' 'falls' 'under' 'the' 'various' 'topics'
#  'discussed' 'in' 'our' 'Op' '##timi' '##zation' 'curriculum' '.' 'Can'
#  'you' 'pl' '##eas' '##e' 'collect' 'it' '?']
# Predicted Labels: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-TIME', 'O', 'B-JOBTITLE', 'I-JOBTITLE', 'I-JOBTITLE', 'I-JOBTITLE', 'O', 'B-COUNTY', 'O', 'O', 'O', 'O', 'O', 'B-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'O', 'B-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'O', 'O', 'O']
# True labels list size = 48
# True token list size = 48
# Predicted labels list size = 48
# Filtered tokens =
#  ['▁A', '▁student', "▁'", '▁s', '▁assessment', '▁was', '▁found', '▁on', '▁device', '▁bearing', '▁IM', '▁#', '▁#', '▁:', '▁06', '▁-', '▁1847', '▁#', '▁-', '▁866', '▁#', '▁#', '▁-', '▁3', '▁.', '▁The', '▁document', '▁falls', '▁under', '▁the', '▁various', '▁topics', '▁discussed', '▁in', '▁our', '▁Op', '▁#', '▁#', '▁curriculum', '▁.', '▁Can', '▁you', '▁pl', '▁#', '▁#', '▁collect', '▁it', '▁?']
# True label =
#  ['O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-PHONEIMEI'
#  'I-PHONEIMEI' 'I-PHONEIMEI' 'I-PHONEIMEI' 'I-PHONEIMEI' 'I-PHONEIMEI'
#  'I-PHONEIMEI' 'I-PHONEIMEI' 'I-PHONEIMEI' 'I-PHONEIMEI' 'O' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-JOBAREA' 'I-JOBAREA' 'I-JOBAREA' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O']
#
# Predicted label =
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-TIME', 'O', 'B-JOBTITLE', 'I-JOBTITLE', 'I-JOBTITLE', 'I-JOBTITLE', 'O', 'B-COUNTY', 'O', 'O', 'O', 'O', 'O', 'B-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'O', 'B-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'O', 'O', 'O']
#
# Accuracy: 0.3542
# Precision: 0.5389
# Recall: 0.3542
# F1-score: 0.4274
# c:\Users\neham\TAMU\research_project_llm\Spring2025\private-data-blocker\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\neham\TAMU\research_project_llm\Spring2025\private-data-blocker\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
tokens = tokenizer.convert_ids_to_tokens(encodings["input_ids"][0])
print(tokens)
# Out:
# ['[CLS]', '▁A', '▁student', "▁'", '▁s', '▁assessment', '▁was', '▁found', '▁on', '▁device', '▁bearing', '▁IM', '▁#', '#', 'E', '▁#', '#', 'I', '▁:', '▁06', '▁-', '▁1847', '▁#', '#', '55', '▁-', '▁866', '▁#', '#', '85', '▁#', '#', '1', '▁-', '▁3', '▁.', '▁The', '▁document', '▁falls', '▁under', '▁the', '▁various', '▁topics', '▁discussed', '▁in', '▁our', '▁Op', '▁#', '#', 't', 'imi', '▁#', '#', 'zation', '▁curriculum', '▁.', '▁Can', '▁you', '▁pl', '▁#', '#', 'ea', 's', '▁#', '#', 'e', '▁collect', '▁it', '▁?', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']

# %%
len(true_labels[0])
# Out:
# 48

# %%
len(aligned_predictions)
# Out:
# 48

# %%
len(true_labels[0])
# Out:
# 48

# %%
true_labels[0]
# Out:
# array(['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'O', 'B-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI',
#        'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI',
#        'I-PHONEIMEI', 'I-PHONEIMEI', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'O', 'O', 'O', 'O', 'B-JOBAREA', 'I-JOBAREA', 'I-JOBAREA', 'O',
#        'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], dtype=object)

# %%
aligned_predictions
# Out:
# ['O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'B-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'B-JOBAREA',
#  'I-JOBAREA',
#  'I-JOBAREA',
#  'O',
#  'O',
#  'O',
#  'O',
#  'B-FIRSTNAME',
#  'I-FIRSTNAME',
#  'I-FIRSTNAME',
#  'O',
#  'O',
#  'O']

# %%
len(all_aligned_predictions)
# Out:
# 10

# %%
flat_predictions = [label for sentence in all_aligned_predictions for label in sentence]

# %%
flat_true_labels = [label for sentence in true_labels for label in sentence]

# %%
# Compute Accuracy, Precision, Recall, and F1-score
accuracy = accuracy_score(flat_true_labels, flat_predictions)
precision, recall, f1, _ = precision_recall_fscore_support(flat_true_labels, flat_predictions, average="weighted")

# Print Evaluation Metrics
print(f"Samples: {samples}")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Samples: 10
# Accuracy: 0.9730
# Precision: 0.9799
# Recall: 0.9730
# F1-score: 0.9754
# c:\Users\neham\TAMU\research_project_llm\Spring2025\private-data-blocker\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\neham\TAMU\research_project_llm\Spring2025\private-data-blocker\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
type(true_labels)
# Out:
# list

# %%
type(all_aligned_predictions)
# Out:
# list

# %%
len(all_aligned_predictions)
# Out:
# 10

# %%
all_aligned_predictions[0]
# Out:
# ['O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'B-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'I-PHONEIMEI',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'B-JOBAREA',
#  'I-JOBAREA',
#  'I-JOBAREA',
#  'O',
#  'O',
#  'O',
#  'O',
#  'B-FIRSTNAME',
#  'I-FIRSTNAME',
#  'I-FIRSTNAME',
#  'O',
#  'O',
#  'O']

# %%
# Out:
# 'E'

# %%
true_labels
# Out:
# 'O'

# %%
# Compare aligned predictions with actual predictions to find the 

prediction_analysis = [] #store the count of TP, FP, FN, TN

for predictions, label_list in zip(all_aligned_predictions, true_labels):
    tp =0
    tn = 0
    fp = 0
    fn =0
    count = 0
    print(f"Prediction = {predictions}, \n True label = {label_list}")
    true_labels_list = label_list.tolist()
    for pred, true_label in zip(predictions, true_labels_list):
        count +=1
        print(f"Pred = {pred}, True label = {true_label}")
        if pred == true_label:
            if pred != 'O':  # Correctly predicted an entity
                tp +=1
            else:
                tn +=1 # Correctly predicted a non-entity
        else:
            if pred!='O' and true_label == 'O':
             # Model falsely predicted an entity when it should be "O"
                fp +=1
            elif pred=='O' and true_label!='O':
            # Model failed to detect an entity (missed it)
                fn +=1
            else:
            # Model predicted the wrong entity (e.g., "B-ORG" instead of "B-PER")
                fp += 1  # Counts as a wrongly identified entity
        print(f"tp = {tp}, fp = {fp}, tn ={tn}, fn={fn}\n")
    prediction_analysis.append({"tp":tp, "fp":fp, "fn":fn, "tn":tn, "tokens":count })
# Out:
# Prediction = ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'I-PHONEIMEI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-JOBAREA', 'I-JOBAREA', 'I-JOBAREA', 'O', 'O', 'O', 'O', 'B-FIRSTNAME', 'I-FIRSTNAME', 'I-FIRSTNAME', 'O', 'O', 'O'],
#  True label = ['O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-PHONEIMEI'
#  'I-PHONEIMEI' 'I-PHONEIMEI' 'I-PHONEIMEI' 'I-PHONEIMEI' 'I-PHONEIMEI'
#  'I-PHONEIMEI' 'I-PHONEIMEI' 'I-PHONEIMEI' 'I-PHONEIMEI' 'O' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-JOBAREA' 'I-JOBAREA' 'I-JOBAREA' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O']
# Pred = O, True label = O
# tp = 0, fp = 0, tn =1, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =2, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =3, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =4, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =5, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =6, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =7, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =8, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =9, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =10, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =11, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =12, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =13, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =14, fn=0
#
# Pred = B-PHONEIMEI, True label = B-PHONEIMEI
# tp = 1, fp = 0, tn =14, fn=0
#
# Pred = I-PHONEIMEI, True label = I-PHONEIMEI
# tp = 2, fp = 0, tn =14, fn=0
#
# Pred = I-PHONEIMEI, True label = I-PHONEIMEI
# tp = 3, fp = 0, tn =14, fn=0
#
# Pred = I-PHONEIMEI, True label = I-PHONEIMEI
# tp = 4, fp = 0, tn =14, fn=0
#
# Pred = I-PHONEIMEI, True label = I-PHONEIMEI
# tp = 5, fp = 0, tn =14, fn=0
#
# Pred = I-PHONEIMEI, True label = I-PHONEIMEI
# tp = 6, fp = 0, tn =14, fn=0
#
# Pred = I-PHONEIMEI, True label = I-PHONEIMEI
# tp = 7, fp = 0, tn =14, fn=0
#
# Pred = I-PHONEIMEI, True label = I-PHONEIMEI
# tp = 8, fp = 0, tn =14, fn=0
#
# Pred = I-PHONEIMEI, True label = I-PHONEIMEI
# tp = 9, fp = 0, tn =14, fn=0
#
# Pred = I-PHONEIMEI, True label = I-PHONEIMEI
# tp = 10, fp = 0, tn =14, fn=0
#
# Pred = O, True label = O
# tp = 10, fp = 0, tn =15, fn=0
#
# Pred = O, True label = O
# tp = 10, fp = 0, tn =16, fn=0
#
# Pred = O, True label = O
# tp = 10, fp = 0, tn =17, fn=0
#
# Pred = O, True label = O
# tp = 10, fp = 0, tn =18, fn=0
#
# Pred = O, True label = O
# tp = 10, fp = 0, tn =19, fn=0
#
# Pred = O, True label = O
# tp = 10, fp = 0, tn =20, fn=0
#
# Pred = O, True label = O
# tp = 10, fp = 0, tn =21, fn=0
#
# Pred = O, True label = O
# tp = 10, fp = 0, tn =22, fn=0
#
# Pred = O, True label = O
# tp = 10, fp = 0, tn =23, fn=0
#
# Pred = O, True label = O
# tp = 10, fp = 0, tn =24, fn=0
#
# Pred = O, True label = O
# tp = 10, fp = 0, tn =25, fn=0
#
# Pred = B-JOBAREA, True label = B-JOBAREA
# tp = 11, fp = 0, tn =25, fn=0
#
# Pred = I-JOBAREA, True label = I-JOBAREA
# tp = 12, fp = 0, tn =25, fn=0
#
# Pred = I-JOBAREA, True label = I-JOBAREA
# tp = 13, fp = 0, tn =25, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =26, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =27, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =28, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =29, fn=0
#
# Pred = B-FIRSTNAME, True label = O
# tp = 13, fp = 1, tn =29, fn=0
#
# Pred = I-FIRSTNAME, True label = O
# tp = 13, fp = 2, tn =29, fn=0
#
# Pred = I-FIRSTNAME, True label = O
# tp = 13, fp = 3, tn =29, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 3, tn =30, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 3, tn =31, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 3, tn =32, fn=0
#
# Prediction = ['O', 'B-FIRSTNAME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'I-VEHICLEVIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  True label = ['O' 'B-FIRSTNAME' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-VEHICLEVIN'
#  'I-VEHICLEVIN' 'I-VEHICLEVIN' 'I-VEHICLEVIN' 'I-VEHICLEVIN'
#  'I-VEHICLEVIN' 'I-VEHICLEVIN' 'I-VEHICLEVIN' 'I-VEHICLEVIN'
#  'I-VEHICLEVIN' 'I-VEHICLEVIN' 'I-VEHICLEVIN' 'I-VEHICLEVIN' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'O']
# Pred = O, True label = O
# tp = 0, fp = 0, tn =1, fn=0
#
# Pred = B-FIRSTNAME, True label = B-FIRSTNAME
# tp = 1, fp = 0, tn =1, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =2, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =3, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =4, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =5, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =6, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =7, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =8, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =9, fn=0
#
# Pred = B-VEHICLEVIN, True label = B-VEHICLEVIN
# tp = 2, fp = 0, tn =9, fn=0
#
# Pred = I-VEHICLEVIN, True label = I-VEHICLEVIN
# tp = 3, fp = 0, tn =9, fn=0
#
# Pred = I-VEHICLEVIN, True label = I-VEHICLEVIN
# tp = 4, fp = 0, tn =9, fn=0
#
# Pred = I-VEHICLEVIN, True label = I-VEHICLEVIN
# tp = 5, fp = 0, tn =9, fn=0
#
# Pred = I-VEHICLEVIN, True label = I-VEHICLEVIN
# tp = 6, fp = 0, tn =9, fn=0
#
# Pred = I-VEHICLEVIN, True label = I-VEHICLEVIN
# tp = 7, fp = 0, tn =9, fn=0
#
# Pred = I-VEHICLEVIN, True label = I-VEHICLEVIN
# tp = 8, fp = 0, tn =9, fn=0
#
# Pred = I-VEHICLEVIN, True label = I-VEHICLEVIN
# tp = 9, fp = 0, tn =9, fn=0
#
# Pred = I-VEHICLEVIN, True label = I-VEHICLEVIN
# tp = 10, fp = 0, tn =9, fn=0
#
# Pred = I-VEHICLEVIN, True label = I-VEHICLEVIN
# tp = 11, fp = 0, tn =9, fn=0
#
# Pred = I-VEHICLEVIN, True label = I-VEHICLEVIN
# tp = 12, fp = 0, tn =9, fn=0
#
# Pred = I-VEHICLEVIN, True label = I-VEHICLEVIN
# tp = 13, fp = 0, tn =9, fn=0
#
# Pred = I-VEHICLEVIN, True label = I-VEHICLEVIN
# tp = 14, fp = 0, tn =9, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =10, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =11, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =12, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =13, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =14, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =15, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =16, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =17, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =18, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =19, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =20, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =21, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =22, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =23, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =24, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =25, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =26, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =27, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =28, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =29, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =30, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =31, fn=0
#
# Prediction = ['B-FIRSTNAME', 'I-FIRSTNAME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-AGE', 'O', 'B-GENDER', 'I-GENDER', 'I-GENDER', 'I-GENDER', 'O', 'B-HEIGHT', 'I-HEIGHT', 'I-HEIGHT', 'I-HEIGHT', 'O'],
#  True label = ['B-FIRSTNAME' 'I-FIRSTNAME' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'B-AGE' 'O' 'B-GENDER' 'I-GENDER' 'I-GENDER'
#  'I-GENDER' 'O' 'B-HEIGHT' 'I-HEIGHT' 'I-HEIGHT' 'I-HEIGHT' 'O']
# Pred = B-FIRSTNAME, True label = B-FIRSTNAME
# tp = 1, fp = 0, tn =0, fn=0
#
# Pred = I-FIRSTNAME, True label = I-FIRSTNAME
# tp = 2, fp = 0, tn =0, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =1, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =2, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =3, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =4, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =5, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =6, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =7, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =8, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =9, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =10, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =11, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =12, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =13, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =14, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =15, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =16, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =17, fn=0
#
# Pred = B-AGE, True label = B-AGE
# tp = 3, fp = 0, tn =17, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =18, fn=0
#
# Pred = B-GENDER, True label = B-GENDER
# tp = 4, fp = 0, tn =18, fn=0
#
# Pred = I-GENDER, True label = I-GENDER
# tp = 5, fp = 0, tn =18, fn=0
#
# Pred = I-GENDER, True label = I-GENDER
# tp = 6, fp = 0, tn =18, fn=0
#
# Pred = I-GENDER, True label = I-GENDER
# tp = 7, fp = 0, tn =18, fn=0
#
# Pred = O, True label = O
# tp = 7, fp = 0, tn =19, fn=0
#
# Pred = B-HEIGHT, True label = B-HEIGHT
# tp = 8, fp = 0, tn =19, fn=0
#
# Pred = I-HEIGHT, True label = I-HEIGHT
# tp = 9, fp = 0, tn =19, fn=0
#
# Pred = I-HEIGHT, True label = I-HEIGHT
# tp = 10, fp = 0, tn =19, fn=0
#
# Pred = I-HEIGHT, True label = I-HEIGHT
# tp = 11, fp = 0, tn =19, fn=0
#
# Pred = O, True label = O
# tp = 11, fp = 0, tn =20, fn=0
#
# Prediction = ['O', 'O', 'O', 'B-ZIPCODE', 'I-ZIPCODE', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'I-CREDITCARDNUMBER', 'O', 'O', 'O', 'O', 'O'],
#  True label = ['O' 'O' 'O' 'B-BUILDINGNUMBER' 'I-BUILDINGNUMBER' 'O' 'O' 'O' 'O' 'O' 'O'
#  'B-MASKEDNUMBER' 'I-MASKEDNUMBER' 'I-MASKEDNUMBER' 'I-MASKEDNUMBER'
#  'I-MASKEDNUMBER' 'I-MASKEDNUMBER' 'I-MASKEDNUMBER' 'I-MASKEDNUMBER'
#  'I-MASKEDNUMBER' 'O' 'O' 'O' 'O' 'O']
# Pred = O, True label = O
# tp = 0, fp = 0, tn =1, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =2, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =3, fn=0
#
# Pred = B-ZIPCODE, True label = B-BUILDINGNUMBER
# tp = 0, fp = 1, tn =3, fn=0
#
# Pred = I-ZIPCODE, True label = I-BUILDINGNUMBER
# tp = 0, fp = 2, tn =3, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 2, tn =4, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 2, tn =5, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 2, tn =6, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 2, tn =7, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 2, tn =8, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 2, tn =9, fn=0
#
# Pred = B-CREDITCARDNUMBER, True label = B-MASKEDNUMBER
# tp = 0, fp = 3, tn =9, fn=0
#
# Pred = I-CREDITCARDNUMBER, True label = I-MASKEDNUMBER
# tp = 0, fp = 4, tn =9, fn=0
#
# Pred = I-CREDITCARDNUMBER, True label = I-MASKEDNUMBER
# tp = 0, fp = 5, tn =9, fn=0
#
# Pred = I-CREDITCARDNUMBER, True label = I-MASKEDNUMBER
# tp = 0, fp = 6, tn =9, fn=0
#
# Pred = I-CREDITCARDNUMBER, True label = I-MASKEDNUMBER
# tp = 0, fp = 7, tn =9, fn=0
#
# Pred = I-CREDITCARDNUMBER, True label = I-MASKEDNUMBER
# tp = 0, fp = 8, tn =9, fn=0
#
# Pred = I-CREDITCARDNUMBER, True label = I-MASKEDNUMBER
# tp = 0, fp = 9, tn =9, fn=0
#
# Pred = I-CREDITCARDNUMBER, True label = I-MASKEDNUMBER
# tp = 0, fp = 10, tn =9, fn=0
#
# Pred = I-CREDITCARDNUMBER, True label = I-MASKEDNUMBER
# tp = 0, fp = 11, tn =9, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 11, tn =10, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 11, tn =11, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 11, tn =12, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 11, tn =13, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 11, tn =14, fn=0
#
# Prediction = ['O', 'B-AGE', 'O', 'O', 'O', 'B-BUILDINGNUMBER', 'I-BUILDINGNUMBER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'O', 'O', 'O', 'O'],
#  True label = ['O' 'B-AGE' 'O' 'O' 'O' 'B-BUILDINGNUMBER' 'I-BUILDINGNUMBER' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-PASSWORD'
#  'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD'
#  'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'O' 'O'
#  'O' 'O']
# Pred = O, True label = O
# tp = 0, fp = 0, tn =1, fn=0
#
# Pred = B-AGE, True label = B-AGE
# tp = 1, fp = 0, tn =1, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =2, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =3, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =4, fn=0
#
# Pred = B-BUILDINGNUMBER, True label = B-BUILDINGNUMBER
# tp = 2, fp = 0, tn =4, fn=0
#
# Pred = I-BUILDINGNUMBER, True label = I-BUILDINGNUMBER
# tp = 3, fp = 0, tn =4, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =5, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =6, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =7, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =8, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =9, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =10, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =11, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =12, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =13, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =14, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =15, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =16, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =17, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =18, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =19, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =20, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =21, fn=0
#
# Pred = O, True label = O
# tp = 3, fp = 0, tn =22, fn=0
#
# Pred = B-PASSWORD, True label = B-PASSWORD
# tp = 4, fp = 0, tn =22, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 5, fp = 0, tn =22, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 6, fp = 0, tn =22, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 7, fp = 0, tn =22, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 8, fp = 0, tn =22, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 9, fp = 0, tn =22, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 10, fp = 0, tn =22, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 11, fp = 0, tn =22, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 12, fp = 0, tn =22, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 13, fp = 0, tn =22, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 14, fp = 0, tn =22, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =23, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =24, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =25, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =26, fn=0
#
# Prediction = ['O', 'O', 'O', 'O', 'O', 'O', 'B-DOB', 'I-DOB', 'I-DOB', 'I-DOB', 'I-DOB', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'I-IPV6', 'O', 'O', 'O', 'O', 'O'],
#  True label = ['O' 'O' 'O' 'O' 'O' 'O' 'B-DOB' 'I-DOB' 'I-DOB' 'I-DOB' 'I-DOB' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-IPV6' 'I-IPV6'
#  'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6'
#  'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6'
#  'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6' 'I-IPV6'
#  'I-IPV6' 'I-IPV6' 'O' 'O' 'O' 'O' 'O']
# Pred = O, True label = O
# tp = 0, fp = 0, tn =1, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =2, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =3, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =4, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =5, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =6, fn=0
#
# Pred = B-DOB, True label = B-DOB
# tp = 1, fp = 0, tn =6, fn=0
#
# Pred = I-DOB, True label = I-DOB
# tp = 2, fp = 0, tn =6, fn=0
#
# Pred = I-DOB, True label = I-DOB
# tp = 3, fp = 0, tn =6, fn=0
#
# Pred = I-DOB, True label = I-DOB
# tp = 4, fp = 0, tn =6, fn=0
#
# Pred = I-DOB, True label = I-DOB
# tp = 5, fp = 0, tn =6, fn=0
#
# Pred = O, True label = O
# tp = 5, fp = 0, tn =7, fn=0
#
# Pred = O, True label = O
# tp = 5, fp = 0, tn =8, fn=0
#
# Pred = O, True label = O
# tp = 5, fp = 0, tn =9, fn=0
#
# Pred = O, True label = O
# tp = 5, fp = 0, tn =10, fn=0
#
# Pred = O, True label = O
# tp = 5, fp = 0, tn =11, fn=0
#
# Pred = O, True label = O
# tp = 5, fp = 0, tn =12, fn=0
#
# Pred = O, True label = O
# tp = 5, fp = 0, tn =13, fn=0
#
# Pred = O, True label = O
# tp = 5, fp = 0, tn =14, fn=0
#
# Pred = O, True label = O
# tp = 5, fp = 0, tn =15, fn=0
#
# Pred = O, True label = O
# tp = 5, fp = 0, tn =16, fn=0
#
# Pred = O, True label = O
# tp = 5, fp = 0, tn =17, fn=0
#
# Pred = O, True label = O
# tp = 5, fp = 0, tn =18, fn=0
#
# Pred = O, True label = O
# tp = 5, fp = 0, tn =19, fn=0
#
# Pred = O, True label = O
# tp = 5, fp = 0, tn =20, fn=0
#
# Pred = B-IPV6, True label = B-IPV6
# tp = 6, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 7, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 8, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 9, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 10, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 11, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 12, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 13, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 14, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 15, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 16, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 17, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 18, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 19, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 20, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 21, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 22, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 23, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 24, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 25, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 26, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 27, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 28, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 29, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 30, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 31, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 32, fp = 0, tn =20, fn=0
#
# Pred = I-IPV6, True label = I-IPV6
# tp = 33, fp = 0, tn =20, fn=0
#
# Pred = O, True label = O
# tp = 33, fp = 0, tn =21, fn=0
#
# Pred = O, True label = O
# tp = 33, fp = 0, tn =22, fn=0
#
# Pred = O, True label = O
# tp = 33, fp = 0, tn =23, fn=0
#
# Pred = O, True label = O
# tp = 33, fp = 0, tn =24, fn=0
#
# Pred = O, True label = O
# tp = 33, fp = 0, tn =25, fn=0
#
# Prediction = ['O', 'B-GENDER', 'I-GENDER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  True label = ['O' 'B-GENDER' 'I-GENDER' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-PASSWORD' 'I-PASSWORD' 'I-PASSWORD'
#  'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD'
#  'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'O' 'O' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O']
# Pred = O, True label = O
# tp = 0, fp = 0, tn =1, fn=0
#
# Pred = B-GENDER, True label = B-GENDER
# tp = 1, fp = 0, tn =1, fn=0
#
# Pred = I-GENDER, True label = I-GENDER
# tp = 2, fp = 0, tn =1, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =2, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =3, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =4, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =5, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =6, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =7, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =8, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =9, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =10, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =11, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =12, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =13, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =14, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =15, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =16, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =17, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =18, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =19, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =20, fn=0
#
# Pred = O, True label = O
# tp = 2, fp = 0, tn =21, fn=0
#
# Pred = B-PASSWORD, True label = B-PASSWORD
# tp = 3, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 4, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 5, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 6, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 7, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 8, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 9, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 10, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 11, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 12, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 13, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 14, fp = 0, tn =21, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =22, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =23, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =24, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =25, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =26, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =27, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =28, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =29, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =30, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =31, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =32, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =33, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =34, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =35, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =36, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =37, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =38, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =39, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =40, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =41, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =42, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =43, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =44, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =45, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =46, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =47, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =48, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =49, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =50, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =51, fn=0
#
# Pred = O, True label = O
# tp = 14, fp = 0, tn =52, fn=0
#
# Prediction = ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'I-USERAGENT', 'O', 'O', 'O', 'O'],
#  True label = ['O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-NEARBYGPSCOORDINATE'
#  'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'O' 'O' 'B-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT'
#  'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT'
#  'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT'
#  'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT'
#  'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT'
#  'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT'
#  'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT'
#  'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'I-USERAGENT' 'O'
#  'O' 'O' 'O']
# Pred = O, True label = O
# tp = 0, fp = 0, tn =1, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =2, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =3, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =4, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =5, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =6, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =7, fn=0
#
# Pred = B-NEARBYGPSCOORDINATE, True label = B-NEARBYGPSCOORDINATE
# tp = 1, fp = 0, tn =7, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 2, fp = 0, tn =7, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 3, fp = 0, tn =7, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 4, fp = 0, tn =7, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 5, fp = 0, tn =7, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 6, fp = 0, tn =7, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 7, fp = 0, tn =7, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 8, fp = 0, tn =7, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 9, fp = 0, tn =7, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 10, fp = 0, tn =7, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 11, fp = 0, tn =7, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 12, fp = 0, tn =7, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 13, fp = 0, tn =7, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =8, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =9, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =10, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =11, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =12, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =13, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =14, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =15, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =16, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =17, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =18, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =19, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =20, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =21, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =22, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =23, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =24, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =25, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =26, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =27, fn=0
#
# Pred = B-USERAGENT, True label = B-USERAGENT
# tp = 14, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 15, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 16, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 17, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 18, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 19, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 20, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 21, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 22, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 23, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 24, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 25, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 26, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 27, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 28, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 29, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 30, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 31, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 32, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 33, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 34, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 35, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 36, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 37, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 38, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 39, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 40, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 41, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 42, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 43, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 44, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 45, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 46, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 47, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 48, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 49, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 50, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 51, fp = 0, tn =27, fn=0
#
# Pred = I-USERAGENT, True label = I-USERAGENT
# tp = 52, fp = 0, tn =27, fn=0
#
# Pred = O, True label = O
# tp = 52, fp = 0, tn =28, fn=0
#
# Pred = O, True label = O
# tp = 52, fp = 0, tn =29, fn=0
#
# Pred = O, True label = O
# tp = 52, fp = 0, tn =30, fn=0
#
# Pred = O, True label = O
# tp = 52, fp = 0, tn =31, fn=0
#
# Prediction = ['B-FIRSTNAME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'I-NEARBYGPSCOORDINATE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'I-PASSWORD', 'O'],
#  True label = ['B-FIRSTNAME' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'B-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE' 'I-NEARBYGPSCOORDINATE'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-PASSWORD' 'I-PASSWORD'
#  'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD'
#  'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'I-PASSWORD' 'O']
# Pred = B-FIRSTNAME, True label = B-FIRSTNAME
# tp = 1, fp = 0, tn =0, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =1, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =2, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =3, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =4, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =5, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =6, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =7, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =8, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =9, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =10, fn=0
#
# Pred = O, True label = O
# tp = 1, fp = 0, tn =11, fn=0
#
# Pred = B-NEARBYGPSCOORDINATE, True label = B-NEARBYGPSCOORDINATE
# tp = 2, fp = 0, tn =11, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 3, fp = 0, tn =11, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 4, fp = 0, tn =11, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 5, fp = 0, tn =11, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 6, fp = 0, tn =11, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 7, fp = 0, tn =11, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 8, fp = 0, tn =11, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 9, fp = 0, tn =11, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 10, fp = 0, tn =11, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 11, fp = 0, tn =11, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 12, fp = 0, tn =11, fn=0
#
# Pred = I-NEARBYGPSCOORDINATE, True label = I-NEARBYGPSCOORDINATE
# tp = 13, fp = 0, tn =11, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =12, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =13, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =14, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =15, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =16, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =17, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =18, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =19, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =20, fn=0
#
# Pred = O, True label = O
# tp = 13, fp = 0, tn =21, fn=0
#
# Pred = B-PASSWORD, True label = B-PASSWORD
# tp = 14, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 15, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 16, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 17, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 18, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 19, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 20, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 21, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 22, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 23, fp = 0, tn =21, fn=0
#
# Pred = I-PASSWORD, True label = I-PASSWORD
# tp = 24, fp = 0, tn =21, fn=0
#
# Pred = O, True label = O
# tp = 24, fp = 0, tn =22, fn=0
#
# Prediction = ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TIME', 'I-TIME', 'I-TIME', 'I-TIME', 'O', 'B-JOBTITLE', 'I-JOBTITLE', 'I-JOBTITLE', 'I-JOBTITLE', 'O', 'B-COUNTY', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'I-EMAIL', 'O', 'O', 'O', 'O', 'O', 'B-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'I-ACCOUNTNUMBER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PIN', 'I-PIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EYECOLOR', 'I-EYECOLOR', 'I-EYECOLOR', 'I-EYECOLOR', 'O'],
#  True label = ['O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-TIME' 'I-TIME' 'I-TIME' 'I-TIME' 'O'
#  'B-JOBTITLE' 'I-JOBTITLE' 'I-JOBTITLE' 'I-JOBTITLE' 'O' 'B-COUNTY' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-EMAIL' 'I-EMAIL' 'I-EMAIL' 'I-EMAIL'
#  'I-EMAIL' 'I-EMAIL' 'I-EMAIL' 'I-EMAIL' 'I-EMAIL' 'O' 'O' 'O' 'O' 'O'
#  'B-ACCOUNTNUMBER' 'I-ACCOUNTNUMBER' 'I-ACCOUNTNUMBER' 'I-ACCOUNTNUMBER'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'B-PIN' 'I-PIN' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-EYECOLOR' 'I-EYECOLOR'
#  'I-EYECOLOR' 'I-EYECOLOR' 'O']
# Pred = O, True label = O
# tp = 0, fp = 0, tn =1, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =2, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =3, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =4, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =5, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =6, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =7, fn=0
#
# Pred = O, True label = O
# tp = 0, fp = 0, tn =8, fn=0
#
# Pred = B-TIME, True label = B-TIME
# tp = 1, fp = 0, tn =8, fn=0
#
# Pred = I-TIME, True label = I-TIME
# tp = 2, fp = 0, tn =8, fn=0
#
# Pred = I-TIME, True label = I-TIME
# tp = 3, fp = 0, tn =8, fn=0
#
# Pred = I-TIME, True label = I-TIME
# tp = 4, fp = 0, tn =8, fn=0
#
# Pred = O, True label = O
# tp = 4, fp = 0, tn =9, fn=0
#
# Pred = B-JOBTITLE, True label = B-JOBTITLE
# tp = 5, fp = 0, tn =9, fn=0
#
# Pred = I-JOBTITLE, True label = I-JOBTITLE
# tp = 6, fp = 0, tn =9, fn=0
#
# Pred = I-JOBTITLE, True label = I-JOBTITLE
# tp = 7, fp = 0, tn =9, fn=0
#
# Pred = I-JOBTITLE, True label = I-JOBTITLE
# tp = 8, fp = 0, tn =9, fn=0
#
# Pred = O, True label = O
# tp = 8, fp = 0, tn =10, fn=0
#
# Pred = B-COUNTY, True label = B-COUNTY
# tp = 9, fp = 0, tn =10, fn=0
#
# Pred = O, True label = O
# tp = 9, fp = 0, tn =11, fn=0
#
# Pred = O, True label = O
# tp = 9, fp = 0, tn =12, fn=0
#
# Pred = O, True label = O
# tp = 9, fp = 0, tn =13, fn=0
#
# Pred = O, True label = O
# tp = 9, fp = 0, tn =14, fn=0
#
# Pred = O, True label = O
# tp = 9, fp = 0, tn =15, fn=0
#
# Pred = O, True label = O
# tp = 9, fp = 0, tn =16, fn=0
#
# Pred = O, True label = O
# tp = 9, fp = 0, tn =17, fn=0
#
# Pred = O, True label = O
# tp = 9, fp = 0, tn =18, fn=0
#
# Pred = O, True label = O
# tp = 9, fp = 0, tn =19, fn=0
#
# Pred = B-EMAIL, True label = B-EMAIL
# tp = 10, fp = 0, tn =19, fn=0
#
# Pred = I-EMAIL, True label = I-EMAIL
# tp = 11, fp = 0, tn =19, fn=0
#
# Pred = I-EMAIL, True label = I-EMAIL
# tp = 12, fp = 0, tn =19, fn=0
#
# Pred = I-EMAIL, True label = I-EMAIL
# tp = 13, fp = 0, tn =19, fn=0
#
# Pred = I-EMAIL, True label = I-EMAIL
# tp = 14, fp = 0, tn =19, fn=0
#
# Pred = I-EMAIL, True label = I-EMAIL
# tp = 15, fp = 0, tn =19, fn=0
#
# Pred = I-EMAIL, True label = I-EMAIL
# tp = 16, fp = 0, tn =19, fn=0
#
# Pred = I-EMAIL, True label = I-EMAIL
# tp = 17, fp = 0, tn =19, fn=0
#
# Pred = I-EMAIL, True label = I-EMAIL
# tp = 18, fp = 0, tn =19, fn=0
#
# Pred = O, True label = O
# tp = 18, fp = 0, tn =20, fn=0
#
# Pred = O, True label = O
# tp = 18, fp = 0, tn =21, fn=0
#
# Pred = O, True label = O
# tp = 18, fp = 0, tn =22, fn=0
#
# Pred = O, True label = O
# tp = 18, fp = 0, tn =23, fn=0
#
# Pred = O, True label = O
# tp = 18, fp = 0, tn =24, fn=0
#
# Pred = B-ACCOUNTNUMBER, True label = B-ACCOUNTNUMBER
# tp = 19, fp = 0, tn =24, fn=0
#
# Pred = I-ACCOUNTNUMBER, True label = I-ACCOUNTNUMBER
# tp = 20, fp = 0, tn =24, fn=0
#
# Pred = I-ACCOUNTNUMBER, True label = I-ACCOUNTNUMBER
# tp = 21, fp = 0, tn =24, fn=0
#
# Pred = I-ACCOUNTNUMBER, True label = I-ACCOUNTNUMBER
# tp = 22, fp = 0, tn =24, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =25, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =26, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =27, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =28, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =29, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =30, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =31, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =32, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =33, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =34, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =35, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =36, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =37, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =38, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =39, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =40, fn=0
#
# Pred = O, True label = O
# tp = 22, fp = 0, tn =41, fn=0
#
# Pred = B-PIN, True label = B-PIN
# tp = 23, fp = 0, tn =41, fn=0
#
# Pred = I-PIN, True label = I-PIN
# tp = 24, fp = 0, tn =41, fn=0
#
# Pred = O, True label = O
# tp = 24, fp = 0, tn =42, fn=0
#
# Pred = O, True label = O
# tp = 24, fp = 0, tn =43, fn=0
#
# Pred = O, True label = O
# tp = 24, fp = 0, tn =44, fn=0
#
# Pred = O, True label = O
# tp = 24, fp = 0, tn =45, fn=0
#
# Pred = O, True label = O
# tp = 24, fp = 0, tn =46, fn=0
#
# Pred = O, True label = O
# tp = 24, fp = 0, tn =47, fn=0
#
# Pred = O, True label = O
# tp = 24, fp = 0, tn =48, fn=0
#
# Pred = B-EYECOLOR, True label = B-EYECOLOR
# tp = 25, fp = 0, tn =48, fn=0
#
# Pred = I-EYECOLOR, True label = I-EYECOLOR
# tp = 26, fp = 0, tn =48, fn=0
#
# Pred = I-EYECOLOR, True label = I-EYECOLOR
# tp = 27, fp = 0, tn =48, fn=0
#
# Pred = I-EYECOLOR, True label = I-EYECOLOR
# tp = 28, fp = 0, tn =48, fn=0
#
# Pred = O, True label = O
# tp = 28, fp = 0, tn =49, fn=0

# %%
print(prediction_analysis)
# Out:
# [{'tp': 13, 'fp': 3, 'fn': 0, 'tn': 32, 'tokens': 48}, {'tp': 14, 'fp': 0, 'fn': 0, 'tn': 31, 'tokens': 45}, {'tp': 11, 'fp': 0, 'fn': 0, 'tn': 20, 'tokens': 31}, {'tp': 0, 'fp': 11, 'fn': 0, 'tn': 14, 'tokens': 25}, {'tp': 14, 'fp': 0, 'fn': 0, 'tn': 26, 'tokens': 40}, {'tp': 33, 'fp': 0, 'fn': 0, 'tn': 25, 'tokens': 58}, {'tp': 14, 'fp': 0, 'fn': 0, 'tn': 52, 'tokens': 66}, {'tp': 52, 'fp': 0, 'fn': 0, 'tn': 31, 'tokens': 83}, {'tp': 24, 'fp': 0, 'fn': 0, 'tn': 22, 'tokens': 46}, {'tp': 28, 'fp': 0, 'fn': 0, 'tn': 49, 'tokens': 77}]

# %%
all_aligned_predictions[3]
# Out:
# ['O',
#  'O',
#  'O',
#  'B-ZIPCODE',
#  'I-ZIPCODE',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'B-CREDITCARDNUMBER',
#  'I-CREDITCARDNUMBER',
#  'I-CREDITCARDNUMBER',
#  'I-CREDITCARDNUMBER',
#  'I-CREDITCARDNUMBER',
#  'I-CREDITCARDNUMBER',
#  'I-CREDITCARDNUMBER',
#  'I-CREDITCARDNUMBER',
#  'I-CREDITCARDNUMBER',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O']

# %%
true_labels[3]
# Out:
# array(['O', 'O', 'O', 'B-BUILDINGNUMBER', 'I-BUILDINGNUMBER', 'O', 'O',
#        'O', 'O', 'O', 'O', 'B-MASKEDNUMBER', 'I-MASKEDNUMBER',
#        'I-MASKEDNUMBER', 'I-MASKEDNUMBER', 'I-MASKEDNUMBER',
#        'I-MASKEDNUMBER', 'I-MASKEDNUMBER', 'I-MASKEDNUMBER',
#        'I-MASKEDNUMBER', 'O', 'O', 'O', 'O', 'O'], dtype=object)
